-- %%
import System.IO.Unsafe (unsafePerformIO)
import qualified Graphics.Gnuplot.Plot.TwoDimensional  as P
import qualified Graphics.Gnuplot.Graph.TwoDimensional as G
import qualified IHaskell.Display                      as D
import Graphics.Gnuplot.Simple

D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.function G.points [1..10] (^2))]

-- %%
D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.function G.points [1..10] (^2))]

-- %%
D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.function G.lines [0,0.01..10] cos)]

-- %%
D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.functions G.lines [0,0.01..10] [sin,cos])]

-- %%
D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.function G.lines (linearScale 1000 (-10,10)) sin)]

-- %%
fibs = 0 : 1 : zipWith (+) fibs (tail fibs) 

D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.list G.listLines (take 30 fibs))]

-- %%
D.Display [unsafePerformIO 
           $ graphDataPNG2P (P.parameterFunction 
                             G.lines
                             (linearScale 1000 (0,2*pi)) (\t -> (sin (2*t), cos t)))]
